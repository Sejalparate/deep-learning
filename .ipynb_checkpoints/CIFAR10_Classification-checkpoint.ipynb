# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, Conv2D, Flatten, MaxPooling2D, GlobalMaxPooling2D, BatchNormalization

# %%
cifar = tf.keras.datasets.cifar10

# %%
(x_train, y_train), (x_test, y_test) = cifar.load_data()

# %%
x_train, x_test = x_train/255.0, x_test/255.0
y_train, y_test = y_train.flatten(), y_test.flatten()
print("x_train.shape:", x_train.shape)
print("y_train.shape:", y_train.shape)
# Out:
# x_train.shape: (50000, 32, 32, 3)
# y_train.shape: (50000,)

# %%
# No. of classes
k = len(set(y_train))
print("No. of classes: ", k)
# Out:
# No. of classes:  10

# %%
# Build the model

i = Input(shape = x_train[0].shape)
x = Conv2D(32, (3, 3), strides = 2, activation = 'relu')(i)
x = Conv2D(64, (3, 3), strides = 2, activation = 'relu')(x)
x = Conv2D(128, (3, 3), strides = 2, activation = 'relu')(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation = 'relu')(x)
x = Dropout(0.5)(x)
x = Dense(k, activation = 'softmax')(x)

model = Model(i, x)

# %%
# Train and fit the model

model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
r = model.fit(x_train, y_train, validation_data = (x_test, y_test), epochs = 15)
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 51s 31ms/step - loss: 1.6136 - accuracy: 0.4108 - val_loss: 1.3936 - val_accuracy: 0.5025
# Epoch 2/15
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.3193 - accuracy: 0.5246 - val_loss: 1.1840 - val_accuracy: 0.5753
# Epoch 3/15
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.2017 - accuracy: 0.5717 - val_loss: 1.0662 - val_accuracy: 0.6234
# Epoch 4/15
# 1563/1563 [==============================] - 48s 31ms/step - loss: 1.1220 - accuracy: 0.6016 - val_loss: 1.0151 - val_accuracy: 0.6351
# Epoch 5/15
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.0631 - accuracy: 0.6225 - val_loss: 0.9944 - val_accuracy: 0.6480
# Epoch 6/15
# 1563/1563 [==============================] - 49s 31ms/step - loss: 1.0128 - accuracy: 0.6406 - val_loss: 0.9358 - val_accuracy: 0.6757
# Epoch 7/15
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.9699 - accuracy: 0.6586 - val_loss: 0.9355 - val_accuracy: 0.6682
# Epoch 8/15
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.9346 - accuracy: 0.6692 - val_loss: 0.9018 - val_accuracy: 0.6880
# Epoch 9/15
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.9027 - accuracy: 0.6803 - val_loss: 0.8890 - val_accuracy: 0.6831
# Epoch 10/15
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.8747 - accuracy: 0.6889 - val_loss: 0.8591 - val_accuracy: 0.7010
# Epoch 11/15
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.8488 - accuracy: 0.6996 - val_loss: 0.8693 - val_accuracy: 0.7011
# Epoch 12/15
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.8294 - accuracy: 0.7038 - val_loss: 0.8712 - val_accuracy: 0.6991
# Epoch 13/15
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.8155 - accuracy: 0.7120 - val_loss: 0.8674 - val_accuracy: 0.7009
# Epoch 14/15
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.8011 - accuracy: 0.7169 - val_loss: 0.8452 - val_accuracy: 0.7127
# Epoch 15/15
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.7811 - accuracy: 0.7237 - val_loss: 0.8317 - val_accuracy: 0.7144

# %%
# Plot loss per iteration
plt.plot(r.history['loss'], label = 'loss')
plt.plot(r.history['val_loss'], label = 'val_loss')
plt.legend();

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label = 'accuracy')
plt.plot(r.history['val_accuracy'], label = 'val_accuracy')
plt.legend();

# %%
# Build the model

i = Input(shape = x_train[0].shape)

x = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
# x = Dropout(0.5)(x)
x = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation = 'relu', padding = 'same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
# x = Dropout(0.5)(x)
x = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation = 'relu', padding = 'same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
# x = Dropout(0.5)(x)

# x = GlobalMaxPooling2D()(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation = 'relu')(x)
x = Dropout(0.5)(x)
x = Dense(k, activation = 'softmax')(x)

model = Model(i, x)

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
# Fit with data augmentation

batch_size = 32
data_generator = tf.keras.preprocessing.image.ImageDataGenerator (width_shift_range = 0.1, height_shift_range = 0.1, 
                                                                  horizontal_flip = True)
train_generator = data_generator.flow(x_train, y_train, batch_size)
steps_per_epoch = x_train.shape[0] // batch_size
s = model.fit_generator(train_generator, validation_data = (x_test, y_test), steps_per_epoch = steps_per_epoch, epochs = 15)
# Out:
# Epoch 1/15
# C:\Users\sejbp\AppData\Local\Temp\ipykernel_12228\1239938698.py:8: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   s = model.fit_generator(train_generator, validation_data = (x_test, y_test), steps_per_epoch = steps_per_epoch, epochs = 15)
# 1562/1562 [==============================] - 335s 211ms/step - loss: 1.6756 - accuracy: 0.4232 - val_loss: 1.2743 - val_accuracy: 0.5364
# Epoch 2/15
# 1562/1562 [==============================] - 326s 209ms/step - loss: 1.2169 - accuracy: 0.5758 - val_loss: 1.0952 - val_accuracy: 0.6327
# Epoch 3/15
# 1562/1562 [==============================] - 325s 208ms/step - loss: 1.0372 - accuracy: 0.6453 - val_loss: 0.9489 - val_accuracy: 0.6748
# Epoch 4/15
# 1562/1562 [==============================] - 340s 217ms/step - loss: 0.9341 - accuracy: 0.6824 - val_loss: 1.0417 - val_accuracy: 0.6575
# Epoch 5/15
# 1562/1562 [==============================] - 360s 230ms/step - loss: 0.8428 - accuracy: 0.7141 - val_loss: 0.8896 - val_accuracy: 0.7120
# Epoch 6/15
# 1562/1562 [==============================] - 327s 210ms/step - loss: 0.7755 - accuracy: 0.7375 - val_loss: 0.7597 - val_accuracy: 0.7491
# Epoch 7/15
# 1562/1562 [==============================] - 329s 211ms/step - loss: 0.7215 - accuracy: 0.7584 - val_loss: 0.7001 - val_accuracy: 0.7671
# Epoch 8/15
# 1562/1562 [==============================] - 327s 209ms/step - loss: 0.6688 - accuracy: 0.7740 - val_loss: 0.6458 - val_accuracy: 0.7824
# Epoch 9/15
# 1562/1562 [==============================] - 334s 214ms/step - loss: 0.6282 - accuracy: 0.7886 - val_loss: 0.5662 - val_accuracy: 0.8034
# Epoch 10/15
# 1562/1562 [==============================] - 331s 212ms/step - loss: 0.5941 - accuracy: 0.7995 - val_loss: 0.7418 - val_accuracy: 0.7672
# Epoch 11/15
# 1562/1562 [==============================] - 289s 185ms/step - loss: 0.5645 - accuracy: 0.8085 - val_loss: 0.5849 - val_accuracy: 0.8023
# Epoch 12/15
# 1562/1562 [==============================] - 283s 181ms/step - loss: 0.5384 - accuracy: 0.8148 - val_loss: 0.4882 - val_accuracy: 0.8398
# Epoch 13/15
# 1562/1562 [==============================] - 293s 187ms/step - loss: 0.5151 - accuracy: 0.8246 - val_loss: 0.5033 - val_accuracy: 0.8362
# Epoch 14/15
# 1562/1562 [==============================] - 290s 186ms/step - loss: 0.5038 - accuracy: 0.8288 - val_loss: 0.6373 - val_accuracy: 0.7849
# Epoch 15/15
# 1562/1562 [==============================] - 307s 197ms/step - loss: 0.4926 - accuracy: 0.8330 - val_loss: 0.6339 - val_accuracy: 0.7859

# %%
# Plot loss per iteration
plt.plot(s.history['loss'], label = 'loss')
plt.plot(s.history['val_loss'], label = 'val_loss')
plt.legend();

# %%
# Plot accuracy per iteration
plt.plot(s.history['accuracy'], label = 'accuracy')
plt.plot(s.history['val_accuracy'], label = 'val_accuracy')
plt.legend();
